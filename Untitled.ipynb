# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 128
CHANNELS = 3
EPOCHS = 30

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PokemonData",
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 20099 files belonging to 151 classes.

# %%
class_names = dataset.class_names

print(len(class_names))
print(class_names[:10])
# Out:
# 151
# ['Abra', 'Aerodactyl', 'Alakazam', 'Arbok', 'Arcanine', 'Articuno', 'Beedrill', 'Bellsprout', 'Blastoise', 'Bulbasaur']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 128, 128, 3)
# [ 75 108  84  96 135  42 111 150 110  35  84  59  57  11 146   5  59  96
#  126  41  96  24  46  17 104  21 100  45  72 124  12 141]

# %%
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
len(dataset)
# Out:
# 629

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 503.20000000000005

# %%
train_ds = dataset.take(503)
len(train_ds)
# Out:
# 503

# %%
test_ds = dataset.skip(503)
len(test_ds)
# Out:
# 126

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 62.900000000000006

# %%
val_ds = test_ds.take(63)
len(val_ds)
# Out:
# 63

# %%
test_ds = test_ds.skip(63)
len(test_ds)
# Out:
# 63

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (503, 62, 64)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.Rescaling(1./255),
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = len(class_names)

model = models.Sequential([
    resize_and_rescale,

    layers.Conv2D(32, (3,3), activation="relu", padding="same"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation="relu", padding="same"),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation="relu", padding="same"),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),

    layers.Dense(128, activation="relu"),
    layers.Dense(n_classes, activation="softmax")
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_7 (Sequential)            │ (32, 128, 128, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (32, 128, 128, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (32, 64, 64, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (32, 64, 64, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_28 (MaxPooling2D)      │ (32, 32, 32, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (32, 32, 32, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_29 (MaxPooling2D)      │ (32, 16, 16, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (32, 32768)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (32, 128)                   │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (32, 151)                   │          19,479 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,307,159 (16.43 MB)
#  Trainable params: 4,307,159 (16.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 73s 141ms/step - accuracy: 0.1522 - loss: 3.8399 - val_accuracy: 0.3836 - val_loss: 2.4385
# Epoch 2/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 72s 144ms/step - accuracy: 0.4799 - loss: 2.0956 - val_accuracy: 0.6460 - val_loss: 1.4427
# Epoch 3/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 79s 158ms/step - accuracy: 0.6778 - loss: 1.2449 - val_accuracy: 0.7893 - val_loss: 0.8729
# Epoch 4/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 82s 164ms/step - accuracy: 0.8142 - loss: 0.6892 - val_accuracy: 0.8619 - val_loss: 0.5502
# Epoch 5/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 84s 166ms/step - accuracy: 0.9038 - loss: 0.3538 - val_accuracy: 0.8951 - val_loss: 0.4559
# Epoch 6/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 86s 170ms/step - accuracy: 0.9452 - loss: 0.1899 - val_accuracy: 0.9115 - val_loss: 0.4550
# Epoch 7/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 76s 151ms/step - accuracy: 0.9599 - loss: 0.1432 - val_accuracy: 0.9228 - val_loss: 0.4288
# Epoch 8/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 70s 140ms/step - accuracy: 0.9700 - loss: 0.1086 - val_accuracy: 0.9299 - val_loss: 0.4426
# Epoch 9/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 71s 140ms/step - accuracy: 0.9688 - loss: 0.1081 - val_accuracy: 0.9171 - val_loss: 0.5065
# Epoch 10/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 70s 140ms/step - accuracy: 0.9733 - loss: 0.0976 - val_accuracy: 0.9294 - val_loss: 0.4593
# Epoch 11/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 71s 141ms/step - accuracy: 0.9754 - loss: 0.0829 - val_accuracy: 0.9309 - val_loss: 0.4502
# Epoch 12/30
# 503/503 ━━━━━━━━━━━━━━━━━━━━ 70s 140ms/step - accuracy: 0.9747 - loss: 0.0877 - val_accuracy: 0.9207 - val_loss: 0.5353

# %%
scores = model.evaluate(test_ds)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9023 - loss: 0.5825

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 30, 'steps': 503}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
type(history.history['loss'])
# Out:
# list

# %%
len(history.history['loss'])
# Out:
# 12

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [3.8398563861846924,
#  2.095618963241577,
#  1.2449098825454712,
#  0.6892302632331848,
#  0.3537714183330536]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, marker='o', label='Training Accuracy')
plt.plot(epochs, val_acc, marker='o', label='Validation Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, marker='o', label='Training Loss')
plt.plot(epochs, val_loss, marker='o', label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np

for images_batch, labels_batch in test_ds.take(1):

    index = 30

    image = images_batch[index].numpy().astype("uint8")
    label = labels_batch[index].numpy()

    plt.figure(figsize=(5,5))
    plt.imshow(image)
    plt.axis("off")

    predictions = model.predict(images_batch)

    predicted_class = np.argmax(predictions[index])

    print("Actual Label    :", class_names[label])
    print("Predicted Label :", class_names[predicted_class])
    print("Confidence      : {:.2f}%".format(np.max(predictions[index]) * 100))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Actual Label    : Kabuto
# Predicted Label : Golem
# Confidence      : 62.08%

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
model.save("pokemon_classifier.keras")

# %%
from tensorflow import keras

loaded_model = keras.models.load_model("pokemon_classifier.keras")

# %%
loaded_model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_7 (Sequential)            │ (32, 128, 128, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (32, 128, 128, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (32, 64, 64, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (32, 64, 64, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_28 (MaxPooling2D)      │ (32, 32, 32, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (32, 32, 32, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_29 (MaxPooling2D)      │ (32, 16, 16, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (32, 32768)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (32, 128)                   │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (32, 151)                   │          19,479 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,921,479 (49.29 MB)
#  Trainable params: 4,307,159 (16.43 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8,614,320 (32.86 MB)

# %%
import json

with open("class_names.json", "w") as f:
    json.dump(class_names, f)

# %%
import json

with open("class_names.json", "r") as f:
    class_names = json.load(f)
